# %%
import pandas as pd

# %%
df = pd.read_csv('Planilha.csv')
df
# Out:
#      Negociation_id_bd  negotiation_id                             seller_id  \
# 0               152130          114920  bc579423-30f5-438c-8a15-1731ff5a1b66
# 1               152117          114921  fd8f557a-6d67-4a4c-8137-a8ccf3ca914f
# 2               152116          114922  f68442a2-676a-4532-86a1-7728076726e6
# 3               152115          114923  f6189c8d-7a53-4a8c-afa0-a3781bd66db7
# 4               152114          114924  f2406317-1668-4ba5-a6c7-2209b66489f0
# ..                 ...             ...                                   ...
# 129              19436           95871  db6383ee-a9dc-4455-8d41-7a9b30cef591
# 130              19435           95872  db39a676-e740-49cd-8bc2-4c51d9891386
# 131              19434           95873  db29f79d-ccec-4206-9885-e1d4125e7320
# 132              19433           95874  db24347c-93f2-424b-87ca-930645c0f86b
# 133              19432           95875  dab2b678-8ce4-4893-913a-cb3c779da35f
#
#             number                         model_tag  \
# 0    5541995659361                      samebrandpdf
# 1    5583996732622                    campanhageral1
# 2    5528999915535                    campanhageral1
# 3    5511943784797                    campanhageral1
# 4    5511944466250                    campanhageral1
# ..             ...                               ...
# 129  5531995164635  campanhaespecialdiadoconsumidor2
# 130  5511990569952                fup2campanhageral2
# 131  5535988269425  campanhaespecialdiadoconsumidor2
# 132  5518981127302  campanhaespecialdiadoconsumidor2
# 133  5541998760031  campanhaespecialdiadoconsumidor2
#
#                                             extra_info         status  \
# 0    {"cnpj":"38193614000100","produto_1":"Equaliv ...     in contact
# 1    {"cnpj":"05476755000180","produto_1":"Mahogany...  first contact
# 2    {"cnpj":"30726805000188","produto_1":"Tubolit ...     in contact
# 3    {"cnpj":"42146434000144","produto_1":"Kit Filt...  first contact
# 4    {"cnpj":"42912192000152","produto_1":"Frascos ...  first contact
# ..                                                 ...            ...
# 129  {"cnpj":"11118506000701","produto_1":"Celular ...  first contact
# 130  {"cnpj":"40680458000153","produto_1":"Kit 2 Es...           fup2
# 131  {"cnpj":"36863331000100","produto_1":"Cabo De ...  first contact
# 132  {"cnpj":"23486289000104","produto_1":"Brinqued...  first contact
# 133  {"cnpj":"47900268000143","produto_1":"Suplemen...  first contact
#
#      sentiments  sentiment_score                 date_contact  \
# 0           NaN              NaN  2024-04-15T21:29:42.799793Z
# 1           NaN              NaN  2024-04-15T19:31:59.850708Z
# 2           NaN              NaN  2024-04-15T19:31:59.339031Z
# 3           NaN              NaN  2024-04-15T19:31:58.829020Z
# 4           NaN              NaN  2024-04-15T19:31:58.373461Z
# ..          ...              ...                          ...
# 129         NaN              NaN  2024-03-15T16:26:29.178033Z
# 130         NaN              NaN  2024-03-15T16:26:28.800038Z
# 131         NaN              NaN  2024-03-15T16:26:28.391843Z
# 132         NaN              NaN  2024-03-15T16:26:27.980767Z
# 133         NaN              NaN  2024-03-15T16:26:27.598377Z
#
#                      last_update strategy_tag           sender_number  \
# 0    2024-04-15T21:37:29.956591Z    marketmap  whatsapp:+551140403063
# 1    2024-04-15T19:31:59.850718Z     campaign  whatsapp:+551140403063
# 2    2024-04-15T19:45:23.764272Z     campaign  whatsapp:+551140403063
# 3    2024-04-15T19:31:58.829031Z     campaign  whatsapp:+551140403063
# 4    2024-04-15T19:31:58.373471Z     campaign  whatsapp:+551140403063
# ..                           ...          ...                     ...
# 129  2024-03-15T16:26:29.178043Z     campaign  whatsapp:+551140403063
# 130  2024-03-20T21:24:57.572528Z     campaign  whatsapp:+551140403063
# 131  2024-03-15T16:26:28.391855Z     campaign  whatsapp:+551140403063
# 132  2024-03-15T16:26:27.980778Z     campaign  whatsapp:+551140403063
# 133  2024-03-15T16:26:27.598388Z     campaign  whatsapp:+551140403063
#
#      number_status
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 129            NaN
# 130            NaN
# 131            NaN
# 132            NaN
# 133            NaN
#
# [134 rows x 14 columns]

# %%
#aqui quero extrairo ojason que tem na coluna extra_info

# %%
import pandas as pd
import json

# Carregando os dados do arquivo CSV
df = pd.read_csv('Planilha.csv')

# Função para converter JSON em dicionário
def parse_json(data):
    try:
        return json.loads(data)
    except json.JSONDecodeError:
        return {}  # Retorna um dicionário vazio em caso de erro

# Aplicar a função na coluna 'extra_info' para extrair o JSON
df['extra_info'] = df['extra_info'].apply(parse_json)

# Normalizar o conteúdo JSON em colunas separadas
json_cols = df['extra_info'].apply(pd.Series)

# Unir as novas colunas ao DataFrame original
df = pd.concat([df, json_cols], axis=1).drop('extra_info', axis=1)

# Preencher todos os valores nulos com espaço em branco
df.fillna('**', inplace=True)
#df.fillna(, inplace=True)

# Encontrar colunas que terminam com números e mesclar os valores
import re

# Extrair sufixos numéricos das colunas e organizar em um dicionário
sufixos = {}
for col in df.columns:
    match = re.search(r'(\d+)$', col)
    if match:
        num = match.group(1)
        if num not in sufixos:
            sufixos[num] = []
        sufixos[num].append(col)

# Para cada grupo de sufixo, mesclar as colunas correspondentes
for num, columns in sufixos.items():
    df['merged_' + num] = df[columns].apply(lambda x: ';'.join(x.astype(str)), axis=1)
    df.drop(columns, axis=1, inplace=True)  # Remover as colunas originais se necessário

# Mostrar o DataFrame atualizado
df = df.astype(str)
df
# Encontrar todas as colunas do DataFrame que não são colunas mescladas
fixed_columns = df.columns.difference(['merged_1', 'merged_2', 'merged_3'])

# Criar um novo DataFrame apenas com as colunas fixas
df_fixed = df[fixed_columns]

# Converter todas as colunas do novo DataFrame para o tipo string
df_fixed = df_fixed.astype(str)

# Mostrar o DataFrame atualizado
print(df_fixed)

# Derreter as colunas mescladas
melted_df = df.melt(id_vars=fixed_columns, value_vars=['merged_1', 'merged_2', 'merged_3'], var_name='Tipo_Mesclado', value_name='Mesclado')
print(melted_df)
# Out:
#     Negociation_id_bd            cnpj count_products count_sku_stockout  \
# 0              152130  38193614000100             10                 **
# 1              152117  05476755000180             **
# 2              152116  30726805000188             **
# 3              152115  42146434000144             **
# 4              152114  42912192000152             **
# ..                ...             ...            ...                ...
# 129             19436  11118506000701             **                 **
# 130             19435  40680458000153             **                 **
# 131             19434  36863331000100             **                 **
# 132             19433  23486289000104             **                 **
# 133             19432  47900268000143             **                 **
#
#     data_hoje                 date_contact                  last_update  \
# 0          **  2024-04-15T21:29:42.799793Z  2024-04-15T21:37:29.956591Z
# 1          **  2024-04-15T19:31:59.850708Z  2024-04-15T19:31:59.850718Z
# 2          **  2024-04-15T19:31:59.339031Z  2024-04-15T19:45:23.764272Z
# 3          **  2024-04-15T19:31:58.829020Z  2024-04-15T19:31:58.829031Z
# 4          **  2024-04-15T19:31:58.373461Z  2024-04-15T19:31:58.373471Z
# ..        ...                          ...                          ...
# 129            2024-03-15T16:26:29.178033Z  2024-03-15T16:26:29.178043Z
# 130            2024-03-15T16:26:28.800038Z  2024-03-20T21:24:57.572528Z
# 131            2024-03-15T16:26:28.391843Z  2024-03-15T16:26:28.391855Z
# 132            2024-03-15T16:26:27.980767Z  2024-03-15T16:26:27.980778Z
# 133            2024-03-15T16:26:27.598377Z  2024-03-15T16:26:27.598388Z
#
#                   messageTag                         model_tag negotiation_id  \
# 0          messagesamebrand1                      samebrandpdf         114920
# 1           messagecampaign1                    campanhageral1         114921
# 2           messagecampaign4                    campanhageral1         114922
# 3           messagecampaign6                    campanhageral1         114923
# 4           messagecampaign3                    campanhageral1         114924
# ..                       ...                               ...            ...
# 129  messagespecialcampaign1  campanhaespecialdiadoconsumidor2          95871
# 130  messagespecialcampaign3                fup2campanhageral2          95872
# 131  messagespecialcampaign2  campanhaespecialdiadoconsumidor2          95873
# 132  messagespecialcampaign2  campanhaespecialdiadoconsumidor2          95874
# 133  messagespecialcampaign3  campanhaespecialdiadoconsumidor2          95875
#
#      ... produtos_campanha                             seller_id  \
# 0    ...                **  bc579423-30f5-438c-8a15-1731ff5a1b66
# 1    ...                 1  fd8f557a-6d67-4a4c-8137-a8ccf3ca914f
# 2    ...                 1  f68442a2-676a-4532-86a1-7728076726e6
# 3    ...                 1  f6189c8d-7a53-4a8c-afa0-a3781bd66db7
# 4    ...                 1  f2406317-1668-4ba5-a6c7-2209b66489f0
# ..   ...               ...                                   ...
# 129  ...                 2  db6383ee-a9dc-4455-8d41-7a9b30cef591
# 130  ...                 2  db39a676-e740-49cd-8bc2-4c51d9891386
# 131  ...                 2  db29f79d-ccec-4206-9885-e1d4125e7320
# 132  ...                 2  db24347c-93f2-424b-87ca-930645c0f86b
# 133  ...                 2  dab2b678-8ce4-4893-913a-cb3c779da35f
#
#               sender_number sentiment_score sentiments  \
# 0    whatsapp:+551140403063              **         **
# 1    whatsapp:+551140403063              **         **
# 2    whatsapp:+551140403063              **         **
# 3    whatsapp:+551140403063              **         **
# 4    whatsapp:+551140403063              **         **
# ..                      ...             ...        ...
# 129  whatsapp:+551140403063              **         **
# 130  whatsapp:+551140403063              **         **
# 131  whatsapp:+551140403063              **         **
# 132  whatsapp:+551140403063              **         **
# 133  whatsapp:+551140403063              **         **
#
#                                             sentiments         specialTag  \
# 0    {"sentiments":["neutro","neutro","neutro","neu...                 **
# 1                                                   **                 **
# 2    {"sentiments":["neutro","neutro","conflito","r...                 **
# 3                                                   **                 **
# 4                                                   **                 **
# ..                                                 ...                ...
# 129                                                 **  dia do consumidor
# 130                                                 **  dia do consumidor
# 131                                                 **  dia do consumidor
# 132                                                 **  dia do consumidor
# 133                                                 **  dia do consumidor
#
#             status strategy_tag                        thread_id
# 0       in contact    marketmap                               **
# 1    first contact     campaign                               **
# 2       in contact     campaign                               **
# 3    first contact     campaign                               **
# 4    first contact     campaign                               **
# ..             ...          ...                              ...
# 129  first contact     campaign  thread_9tEJsbcEjhsge6ExpDlvozCa
# 130           fup2     campaign  thread_tqxBwtglfjesW1waTbpTG6PR
# 131  first contact     campaign  thread_NQH4ZsoCzUN4Go6WeHzAA10G
# 132  first contact     campaign  thread_Z7jLdYaVm59fev932gCJlc1g
# 133  first contact     campaign  thread_OeMBcVngojG3Fs9bvFTrun6i
#
# [134 rows x 22 columns]
# C:\Users\matheus.marchiore\AppData\Local\Temp\ipykernel_2052\1161031850.py:24: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '**' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('**', inplace=True)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2052\1161031850.py in ?()
# ---> 61 import pandas as pd
#      62 import json
#      63
#      64 # Carregando os dados do arquivo CSV
#
# c:\Users\matheus.marchiore\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in ?(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    9911         value_name: Hashable = "value",
#    9912         col_level: Level | None = None,
#    9913         ignore_index: bool = True,
#    9914     ) -> DataFrame:
# -> 9915         return melt(
#    9916             self,
#    9917             id_vars=id_vars,
#    9918             value_vars=value_vars,
#
# c:\Users\matheus.marchiore\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\melt.py in ?(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#     106
#     107     mdata: dict[Hashable, AnyArrayLike] = {}
#     108     for col in id_vars:
#     109         id_data = frame.pop(col)
# --> 110         if not isinstance(id_data.dtype, np.dtype):
#     111             # i.e. ExtensionDtype
#     112             if num_cols_adjusted > 0:
#     113                 mdata[col] = concat([id_data] * num_cols_adjusted, ignore_index=True)
#
# c:\Users\matheus.marchiore\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
import pandas as pd
import json

# Carregando os dados do arquivo CSV
df = pd.read_csv('Planilha.csv')

# Função para converter JSON em dicionário
def parse_json(data):
    try:
        return json.loads(data)
    except json.JSONDecodeError:
        return {}  # Retorna um dicionário vazio em caso de erro

# Aplicar a função na coluna 'extra_info' para extrair o JSON
df['extra_info'] = df['extra_info'].apply(parse_json)

# Normalizar o conteúdo JSON em colunas separadas
json_cols = df['extra_info'].apply(pd.Series)

# Unir as novas colunas ao DataFrame original
df = pd.concat([df, json_cols], axis=1).drop('extra_info', axis=1)

# Preencher todos os valores nulos com espaço em branco
df.fillna('**', inplace=True)

# Encontrar colunas que terminam com números e mesclar os valores
import re

# Extrair sufixos numéricos das colunas e organizar em um dicionário
sufixos = {}
for col in df.columns:
    match = re.search(r'(\d+)$', col)
    if match:
        num = match.group(1)
        if num not in sufixos:
            sufixos[num] = []
        sufixos[num].append(col)

# Para cada grupo de sufixo, mesclar as colunas correspondentes
for num, columns in sufixos.items():
    df['merged_' + num] = df[columns].apply(lambda x: ';'.join(x.astype(str)), axis=1)
    df.drop(columns, axis=1, inplace=True)  # Remover as colunas originais se necessário

# Mostrar o DataFrame atualizado
df = df.astype(str)
df
# Out:
# C:\Users\matheus.marchiore\AppData\Local\Temp\ipykernel_2052\1445045308.py:24: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '**' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('**', inplace=True)
#     Negociation_id_bd negotiation_id                             seller_id  \
# 0              152130         114920  bc579423-30f5-438c-8a15-1731ff5a1b66
# 1              152117         114921  fd8f557a-6d67-4a4c-8137-a8ccf3ca914f
# 2              152116         114922  f68442a2-676a-4532-86a1-7728076726e6
# 3              152115         114923  f6189c8d-7a53-4a8c-afa0-a3781bd66db7
# 4              152114         114924  f2406317-1668-4ba5-a6c7-2209b66489f0
# ..                ...            ...                                   ...
# 129             19436          95871  db6383ee-a9dc-4455-8d41-7a9b30cef591
# 130             19435          95872  db39a676-e740-49cd-8bc2-4c51d9891386
# 131             19434          95873  db29f79d-ccec-4206-9885-e1d4125e7320
# 132             19433          95874  db24347c-93f2-424b-87ca-930645c0f86b
# 133             19432          95875  dab2b678-8ce4-4893-913a-cb3c779da35f
#
#             number                         model_tag         status  \
# 0    5541995659361                      samebrandpdf     in contact
# 1    5583996732622                    campanhageral1  first contact
# 2    5528999915535                    campanhageral1     in contact
# 3    5511943784797                    campanhageral1  first contact
# 4    5511944466250                    campanhageral1  first contact
# ..             ...                               ...            ...
# 129  5531995164635  campanhaespecialdiadoconsumidor2  first contact
# 130  5511990569952                fup2campanhageral2           fup2
# 131  5535988269425  campanhaespecialdiadoconsumidor2  first contact
# 132  5518981127302  campanhaespecialdiadoconsumidor2  first contact
# 133  5541998760031  campanhaespecialdiadoconsumidor2  first contact
#
#     sentiments sentiment_score                 date_contact  \
# 0           **              **  2024-04-15T21:29:42.799793Z
# 1           **              **  2024-04-15T19:31:59.850708Z
# 2           **              **  2024-04-15T19:31:59.339031Z
# 3           **              **  2024-04-15T19:31:58.829020Z
# 4           **              **  2024-04-15T19:31:58.373461Z
# ..         ...             ...                          ...
# 129         **              **  2024-03-15T16:26:29.178033Z
# 130         **              **  2024-03-15T16:26:28.800038Z
# 131         **              **  2024-03-15T16:26:28.391843Z
# 132         **              **  2024-03-15T16:26:27.980767Z
# 133         **              **  2024-03-15T16:26:27.598377Z
#
#                      last_update  ...               messageTag  \
# 0    2024-04-15T21:37:29.956591Z  ...        messagesamebrand1
# 1    2024-04-15T19:31:59.850718Z  ...         messagecampaign1
# 2    2024-04-15T19:45:23.764272Z  ...         messagecampaign4
# 3    2024-04-15T19:31:58.829031Z  ...         messagecampaign6
# 4    2024-04-15T19:31:58.373471Z  ...         messagecampaign3
# ..                           ...  ...                      ...
# 129  2024-03-15T16:26:29.178043Z  ...  messagespecialcampaign1
# 130  2024-03-20T21:24:57.572528Z  ...  messagespecialcampaign3
# 131  2024-03-15T16:26:28.391855Z  ...  messagespecialcampaign2
# 132  2024-03-15T16:26:27.980778Z  ...  messagespecialcampaign2
# 133  2024-03-15T16:26:27.598388Z  ...  messagespecialcampaign3
#
#                                             sentiments count_sku_stockout  \
# 0    {"sentiments":["neutro","neutro","neutro","neu...                 **
# 1                                                   **
# 2    {"sentiments":["neutro","neutro","conflito","r...
# 3                                                   **
# 4                                                   **
# ..                                                 ...                ...
# 129                                                 **                 **
# 130                                                 **                 **
# 131                                                 **                 **
# 132                                                 **                 **
# 133                                                 **                 **
#
#     produtos_campanha                        thread_id data_hoje  \
# 0                  **                               **        **
# 1                   1                               **        **
# 2                   1                               **        **
# 3                   1                               **        **
# 4                   1                               **        **
# ..                ...                              ...       ...
# 129                 2  thread_9tEJsbcEjhsge6ExpDlvozCa
# 130                 2  thread_tqxBwtglfjesW1waTbpTG6PR
# 131                 2  thread_NQH4ZsoCzUN4Go6WeHzAA10G
# 132                 2  thread_Z7jLdYaVm59fev932gCJlc1g
# 133                 2  thread_OeMBcVngojG3Fs9bvFTrun6i
#
#             specialTag                                           merged_1  \
# 0                   **  Equaliv Body Protein Cacau 100% Isolado Coláge...
# 1                   **  Mahogany Hidratante Desodorante Corporal Pytho...
# 2                   **  Tubolit  Massa Epóxi A+B 300G;**;**;**;PRDB0WQ...
# 3                   **  Kit Filtros Bob Cat A220 A300 T200 T550 T590 S...
# 4                   **  Frascos Dispenser Ambar 3Pçs Shampoo Condicion...
# ..                 ...                                                ...
# 129  dia do consumidor  Celular De Mesa Aquário Para Dois Chip Anatel ...
# 130  dia do consumidor  Kit 2 Escova Vassourinha Espanador De Pó Limpa...
# 131  dia do consumidor  Cabo De Alarme 2 Pares 0,40mm Megatron, Cobre,...
# 132  dia do consumidor  Brinquedo De Praia Regador Infantil De Plástic...
# 133  dia do consumidor  Suplemento Alimentar Para Cães Nutrafases Ômeg...
#
#                                               merged_2  \
# 0    Equaliv Body Protein 450G Proteina Isolada;Equ...
# 1                         ;**;**;**;;;;;**;**;**;**;**
# 2                         ;**;**;**;;;;;**;**;**;**;**
# 3                         ;**;**;**;;;;;**;**;**;**;**
# 4                         ;**;**;**;;;;;**;**;**;**;**
# ..                                                 ...
# 129  Fechadura Digital Fr 210;**;**;**;PRDX709VCMJS...
# 130  Escova Espanadeira Cerdas Macias Limpeza Estof...
# 131  Cabo para camera de segurança bipolar cftv 100...
# 132  Boneca Sweet Reborn Primeira Vacina Acessórios...
# 133  Suplemento Alimentar - Nutrafases Ômega3 Com 2...
#
#                                               merged_3
# 0    Escova Rotativa 1200W Bivolt Essenza - Eb092 -...
# 1                         ;**;**;**;;;;;**;**;**;**;**
# 2                         ;**;**;**;;;;;**;**;**;**;**
# 3                         ;**;**;**;;;;;**;**;**;**;**
# 4                         ;**;**;**;;;;;**;**;**;**;**
# ..                                                 ...
# 129                                 ;**;**;**;;;;;;;;;
# 130                                 ;**;**;**;;;;;;;;;
# 131                                 ;**;**;**;;;;;;;;;
# 132                                 ;**;**;**;;;;;;;;;
# 133                                 ;**;**;**;;;;;;;;;
#
# [134 rows x 25 columns]

# %%
fixed_columns = df.columns.difference(['merged_1', 'merged_2', 'merged_3'])
df[fixed_columns] = df[fixed_columns].astype(str)
print(fixed_columns)
df.melt(id_vars=fixed_columns, value_vars=['merged_1', 'merged_2', 'merged_3'], var_name='Tipo_Mesclado', value_name='Mesclado')
# # Derretendo as colunas 'merged'
#df_melted = df.melt(id_vars=fixed_columns, var_name='Mesclado_Type', value_name='Mesclado')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2052\3739751440.py in ?()
# ----> 2 fixed_columns = df.columns.difference(['merged_1', 'merged_2', 'merged_3'])
#       3 df[fixed_columns] = df[fixed_columns].astype(str)
#       4 print(fixed_columns)
#       5 df.melt(id_vars=fixed_columns, value_vars=['merged_1', 'merged_2', 'merged_3'], var_name='Tipo_Mesclado', value_name='Mesclado')
#
# c:\Users\matheus.marchiore\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4283
#    4284         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    4285             self._setitem_frame(key, value)
#    4286         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4287             self._setitem_array(key, value)
#    4288         elif isinstance(value, DataFrame):
#    4289             self._set_item_frame_value(key, value)
#    4290         elif (
#
# c:\Users\matheus.marchiore\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4327
#    4328             if isinstance(value, DataFrame):
#    4329                 check_key_length(self.columns, key, value)
#    4330                 for k1, k2 in zip(key, value.columns):
# -> 4331                     self[k1] = value[k2]
#    4332
#    4333             elif not is_list_like(value):
#    4334                 for col in key:
#
# c:\Users\matheus.marchiore\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4285             self._setitem_frame(key, value)
#    4286         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4287             self._setitem_array(key, value)
#    4288         elif isinstance(value, DataFrame):
# -> 4289             self._set_item_frame_value(key, value)
#    4290         elif (
#    4291             is_list_like(value)
#    4292             and not self.columns.is_unique
#
# c:\Users\matheus.marchiore\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4413             loc = self.columns.get_loc(key)
#    4414             cols = self.columns[loc]
#    4415             len_cols = 1 if is_scalar(cols) or isinstance(cols, tuple) else len(cols)
#    4416             if len_cols != len(value.columns):
# -> 4417                 raise ValueError("Columns must be same length as key")
#    4418
#    4419             # align right-hand-side columns if self.columns
#    4420             # is multi-index and self[key] is a sub-frame
#
# ValueError: Columns must be same length as key

# %%
import pandas as pd
import json
import re

# Carregando os dados do arquivo CSV
df = pd.read_csv('Planilha.csv')

# Função para converter JSON em dicionário
def parse_json(data):
    try:
        return json.loads(data)
    except json.JSONDecodeError:
        return {}  # Retorna um dicionário vazio em caso de erro

# Aplicar a função na coluna 'extra_info' para extrair o JSON
df['extra_info'] = df['extra_info'].apply(parse_json)

# Normalizar o conteúdo JSON em colunas separadas
json_cols = df['extra_info'].apply(pd.Series)

# Unir as novas colunas ao DataFrame original
df = pd.concat([df, json_cols], axis=1).drop('extra_info', axis=1)

# Preencher todos os valores nulos com espaço em branco
df.fillna(' ', inplace=True)

# Encontrar colunas que terminam com números e mesclar os valores
sufixos = {}
for col in df.columns:
    match = re.search(r'(\d+)$', col)
    if match:
        num = match.group(1)
        if num not in sufixos:
            sufixos[num] = []
        sufixos[num].append(col)

# Para cada grupo de sufixo, mesclar as colunas correspondentes
for num, columns in sufixos.items():
    df['merged_' + num] = df[columns].apply(lambda x: ';'.join(x.astype(str)), axis=1)
    df.drop(columns, axis=1, inplace=True)  # Remover as colunas originais se necessário

# Mostrar o DataFrame atualizado
print(df)

# Encontrar as colunas fixas após a mesclagem
fixed_columns = df.columns.difference(['merged_1', 'merged_2', 'merged_3'])
print(fixed_columns)

# Derreter as colunas mescladas
melted_df = df.melt(id_vars=fixed_columns, value_vars=['merged_1', 'merged_2', 'merged_3'], var_name='Tipo_Mesclado', value_name='Mesclado')
print(melted_df)
# Out:
#      Negociation_id_bd  negotiation_id                             seller_id  \
# 0               152130          114920  bc579423-30f5-438c-8a15-1731ff5a1b66
# 1               152117          114921  fd8f557a-6d67-4a4c-8137-a8ccf3ca914f
# 2               152116          114922  f68442a2-676a-4532-86a1-7728076726e6
# 3               152115          114923  f6189c8d-7a53-4a8c-afa0-a3781bd66db7
# 4               152114          114924  f2406317-1668-4ba5-a6c7-2209b66489f0
# ..                 ...             ...                                   ...
# 129              19436           95871  db6383ee-a9dc-4455-8d41-7a9b30cef591
# 130              19435           95872  db39a676-e740-49cd-8bc2-4c51d9891386
# 131              19434           95873  db29f79d-ccec-4206-9885-e1d4125e7320
# 132              19433           95874  db24347c-93f2-424b-87ca-930645c0f86b
# 133              19432           95875  dab2b678-8ce4-4893-913a-cb3c779da35f
#
#             number                         model_tag         status  \
# 0    5541995659361                      samebrandpdf     in contact
# 1    5583996732622                    campanhageral1  first contact
# 2    5528999915535                    campanhageral1     in contact
# 3    5511943784797                    campanhageral1  first contact
# 4    5511944466250                    campanhageral1  first contact
# ..             ...                               ...            ...
# 129  5531995164635  campanhaespecialdiadoconsumidor2  first contact
# 130  5511990569952                fup2campanhageral2           fup2
# 131  5535988269425  campanhaespecialdiadoconsumidor2  first contact
# 132  5518981127302  campanhaespecialdiadoconsumidor2  first contact
# 133  5541998760031  campanhaespecialdiadoconsumidor2  first contact
#
#     sentiments sentiment_score                 date_contact  \
# 0                               2024-04-15T21:29:42.799793Z
# 1                               2024-04-15T19:31:59.850708Z
# 2                               2024-04-15T19:31:59.339031Z
# 3                               2024-04-15T19:31:58.829020Z
# 4                               2024-04-15T19:31:58.373461Z
# ..         ...             ...                          ...
# 129                             2024-03-15T16:26:29.178033Z
# 130                             2024-03-15T16:26:28.800038Z
# 131                             2024-03-15T16:26:28.391843Z
# 132                             2024-03-15T16:26:27.980767Z
# 133                             2024-03-15T16:26:27.598377Z
#
#                      last_update  ...               messageTag  \
# 0    2024-04-15T21:37:29.956591Z  ...        messagesamebrand1
# 1    2024-04-15T19:31:59.850718Z  ...         messagecampaign1
# 2    2024-04-15T19:45:23.764272Z  ...         messagecampaign4
# 3    2024-04-15T19:31:58.829031Z  ...         messagecampaign6
# 4    2024-04-15T19:31:58.373471Z  ...         messagecampaign3
# ..                           ...  ...                      ...
# 129  2024-03-15T16:26:29.178043Z  ...  messagespecialcampaign1
# 130  2024-03-20T21:24:57.572528Z  ...  messagespecialcampaign3
# 131  2024-03-15T16:26:28.391855Z  ...  messagespecialcampaign2
# 132  2024-03-15T16:26:27.980778Z  ...  messagespecialcampaign2
# 133  2024-03-15T16:26:27.598388Z  ...  messagespecialcampaign3
#
#                                             sentiments count_sku_stockout  \
# 0    {"sentiments":["neutro","neutro","neutro","neu...
# 1
# 2    {"sentiments":["neutro","neutro","conflito","r...
# 3
# 4
# ..                                                 ...                ...
# 129
# 130
# 131
# 132
# 133
#
#     produtos_campanha                        thread_id data_hoje  \
# 0
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ..                ...                              ...       ...
# 129                 2  thread_9tEJsbcEjhsge6ExpDlvozCa
# 130                 2  thread_tqxBwtglfjesW1waTbpTG6PR
# 131                 2  thread_NQH4ZsoCzUN4Go6WeHzAA10G
# 132                 2  thread_Z7jLdYaVm59fev932gCJlc1g
# 133                 2  thread_OeMBcVngojG3Fs9bvFTrun6i
#
#             specialTag                                           merged_1  \
# 0                       Equaliv Body Protein Cacau 100% Isolado Coláge...
# 1                       Mahogany Hidratante Desodorante Corporal Pytho...
# 2                       Tubolit  Massa Epóxi A+B 300G; ; ; ;PRDB0WQXUI...
# 3                       Kit Filtros Bob Cat A220 A300 T200 T550 T590 S...
# 4                       Frascos Dispenser Ambar 3Pçs Shampoo Condicion...
# ..                 ...                                                ...
# 129  dia do consumidor  Celular De Mesa Aquário Para Dois Chip Anatel ...
# 130  dia do consumidor  Kit 2 Escova Vassourinha Espanador De Pó Limpa...
# 131  dia do consumidor  Cabo De Alarme 2 Pares 0,40mm Megatron, Cobre,...
# 132  dia do consumidor  Brinquedo De Praia Regador Infantil De Plástic...
# 133  dia do consumidor  Suplemento Alimentar Para Cães Nutrafases Ômeg...
#
#                                               merged_2  \
# 0    Equaliv Body Protein 450G Proteina Isolada;Equ...
# 1                                 ; ; ; ;;;;; ; ; ; ;
# 2                                 ; ; ; ;;;;; ; ; ; ;
# 3                                 ; ; ; ;;;;; ; ; ; ;
# 4                                 ; ; ; ;;;;; ; ; ; ;
# ..                                                 ...
# 129  Fechadura Digital Fr 210; ; ; ;PRDX709VCMJSVL0...
# 130  Escova Espanadeira Cerdas Macias Limpeza Estof...
# 131  Cabo para camera de segurança bipolar cftv 100...
# 132  Boneca Sweet Reborn Primeira Vacina Acessórios...
# 133  Suplemento Alimentar - Nutrafases Ômega3 Com 2...
#
#                                               merged_3
# 0    Escova Rotativa 1200W Bivolt Essenza - Eb092 -...
# 1                                 ; ; ; ;;;;; ; ; ; ;
# 2                                 ; ; ; ;;;;; ; ; ; ;
# 3                                 ; ; ; ;;;;; ; ; ; ;
# 4                                 ; ; ; ;;;;; ; ; ; ;
# ..                                                 ...
# 129                                    ; ; ; ;;;;;;;;;
# 130                                    ; ; ; ;;;;;;;;;
# 131                                    ; ; ; ;;;;;;;;;
# 132                                    ; ; ; ;;;;;;;;;
# 133                                    ; ; ; ;;;;;;;;;
#
# [134 rows x 25 columns]
# Index(['Negociation_id_bd', 'cnpj', 'count_products', 'count_sku_stockout',
#        'data_hoje', 'date_contact', 'last_update', 'messageTag', 'model_tag',
#        'negotiation_id', 'number', 'number_status', 'produtos_campanha',
#        'seller_id', 'sender_number', 'sentiment_score', 'sentiments',
#        'specialTag', 'status', 'strategy_tag', 'thread_id'],
#       dtype='object')
# C:\Users\matheus.marchiore\AppData\Local\Temp\ipykernel_2052\1101604325.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value ' ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna(' ', inplace=True)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2052\1101604325.py in ?()
# ---> 50 import pandas as pd
#      51 import json
#      52 import re
#      53
#
# c:\Users\matheus.marchiore\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in ?(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    9911         value_name: Hashable = "value",
#    9912         col_level: Level | None = None,
#    9913         ignore_index: bool = True,
#    9914     ) -> DataFrame:
# -> 9915         return melt(
#    9916             self,
#    9917             id_vars=id_vars,
#    9918             value_vars=value_vars,
#
# c:\Users\matheus.marchiore\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\melt.py in ?(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#     106
#     107     mdata: dict[Hashable, AnyArrayLike] = {}
#     108     for col in id_vars:
#     109         id_data = frame.pop(col)
# --> 110         if not isinstance(id_data.dtype, np.dtype):
#     111             # i.e. ExtensionDtype
#     112             if num_cols_adjusted > 0:
#     113                 mdata[col] = concat([id_data] * num_cols_adjusted, ignore_index=True)
#
# c:\Users\matheus.marchiore\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
import pandas as pd
import json
import re

# Carregando os dados do arquivo CSV
df = pd.read_csv('Planilha.csv')

# Função para converter JSON em dicionário
def parse_json(data):
    try:
        return json.loads(data)
    except json.JSONDecodeError:
        return {}  # Retorna um dicionário vazio em caso de erro

# Aplicar a função na coluna 'extra_info' para extrair o JSON
df['extra_info'] = df['extra_info'].apply(parse_json)

# Normalizar o conteúdo JSON em colunas separadas
json_cols = df['extra_info'].apply(pd.Series)

# Unir as novas colunas ao DataFrame original
df = pd.concat([df, json_cols], axis=1).drop('extra_info', axis=1)

# Preencher todos os valores nulos com espaço em branco
df.fillna(' ', inplace=True)

# Encontrar colunas que terminam com números e mesclar os valores
sufixos = {}
for col in df.columns:
    match = re.search(r'(\d+)$', col)
    if match:
        num = match.group(1)
        if num not in sufixos:
            sufixos[num] = []
        sufixos[num].append(col)

# Para cada grupo de sufixo, mesclar as colunas correspondentes
for num, columns in sufixos.items():
    df['merged_' + num] = df[columns].apply(lambda x: ';'.join(x.astype(str)), axis=1)
    df.drop(columns, axis=1, inplace=True)  # Remover as colunas originais se necessário

# Mostrar o DataFrame atualizado
print(df)

# Encontrar as colunas fixas após a mesclagem
fixed_columns = [col for col in df.columns if col not in ['merged_1', 'merged_2', 'merged_3']]
print(fixed_columns)

# Derreter as colunas mescladas
melted_df = df.melt(id_vars=fixed_columns, value_vars=['merged_1', 'merged_2', 'merged_3'], var_name='Tipo_Mesclado', value_name='Mesclado')
print(melted_df)
# Out:
#      Negociation_id_bd  negotiation_id                             seller_id  \
# 0               152130          114920  bc579423-30f5-438c-8a15-1731ff5a1b66
# 1               152117          114921  fd8f557a-6d67-4a4c-8137-a8ccf3ca914f
# 2               152116          114922  f68442a2-676a-4532-86a1-7728076726e6
# 3               152115          114923  f6189c8d-7a53-4a8c-afa0-a3781bd66db7
# 4               152114          114924  f2406317-1668-4ba5-a6c7-2209b66489f0
# ..                 ...             ...                                   ...
# 129              19436           95871  db6383ee-a9dc-4455-8d41-7a9b30cef591
# 130              19435           95872  db39a676-e740-49cd-8bc2-4c51d9891386
# 131              19434           95873  db29f79d-ccec-4206-9885-e1d4125e7320
# 132              19433           95874  db24347c-93f2-424b-87ca-930645c0f86b
# 133              19432           95875  dab2b678-8ce4-4893-913a-cb3c779da35f
#
#             number                         model_tag         status  \
# 0    5541995659361                      samebrandpdf     in contact
# 1    5583996732622                    campanhageral1  first contact
# 2    5528999915535                    campanhageral1     in contact
# 3    5511943784797                    campanhageral1  first contact
# 4    5511944466250                    campanhageral1  first contact
# ..             ...                               ...            ...
# 129  5531995164635  campanhaespecialdiadoconsumidor2  first contact
# 130  5511990569952                fup2campanhageral2           fup2
# 131  5535988269425  campanhaespecialdiadoconsumidor2  first contact
# 132  5518981127302  campanhaespecialdiadoconsumidor2  first contact
# 133  5541998760031  campanhaespecialdiadoconsumidor2  first contact
#
#     sentiments sentiment_score                 date_contact  \
# 0                               2024-04-15T21:29:42.799793Z
# 1                               2024-04-15T19:31:59.850708Z
# 2                               2024-04-15T19:31:59.339031Z
# 3                               2024-04-15T19:31:58.829020Z
# 4                               2024-04-15T19:31:58.373461Z
# ..         ...             ...                          ...
# 129                             2024-03-15T16:26:29.178033Z
# 130                             2024-03-15T16:26:28.800038Z
# 131                             2024-03-15T16:26:28.391843Z
# 132                             2024-03-15T16:26:27.980767Z
# 133                             2024-03-15T16:26:27.598377Z
#
#                      last_update  ...               messageTag  \
# 0    2024-04-15T21:37:29.956591Z  ...        messagesamebrand1
# 1    2024-04-15T19:31:59.850718Z  ...         messagecampaign1
# 2    2024-04-15T19:45:23.764272Z  ...         messagecampaign4
# 3    2024-04-15T19:31:58.829031Z  ...         messagecampaign6
# 4    2024-04-15T19:31:58.373471Z  ...         messagecampaign3
# ..                           ...  ...                      ...
# 129  2024-03-15T16:26:29.178043Z  ...  messagespecialcampaign1
# 130  2024-03-20T21:24:57.572528Z  ...  messagespecialcampaign3
# 131  2024-03-15T16:26:28.391855Z  ...  messagespecialcampaign2
# 132  2024-03-15T16:26:27.980778Z  ...  messagespecialcampaign2
# 133  2024-03-15T16:26:27.598388Z  ...  messagespecialcampaign3
#
#                                             sentiments count_sku_stockout  \
# 0    {"sentiments":["neutro","neutro","neutro","neu...
# 1
# 2    {"sentiments":["neutro","neutro","conflito","r...
# 3
# 4
# ..                                                 ...                ...
# 129
# 130
# 131
# 132
# 133
#
#     produtos_campanha                        thread_id data_hoje  \
# 0
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ..                ...                              ...       ...
# 129                 2  thread_9tEJsbcEjhsge6ExpDlvozCa
# 130                 2  thread_tqxBwtglfjesW1waTbpTG6PR
# 131                 2  thread_NQH4ZsoCzUN4Go6WeHzAA10G
# 132                 2  thread_Z7jLdYaVm59fev932gCJlc1g
# 133                 2  thread_OeMBcVngojG3Fs9bvFTrun6i
#
#             specialTag                                           merged_1  \
# 0                       Equaliv Body Protein Cacau 100% Isolado Coláge...
# 1                       Mahogany Hidratante Desodorante Corporal Pytho...
# 2                       Tubolit  Massa Epóxi A+B 300G; ; ; ;PRDB0WQXUI...
# 3                       Kit Filtros Bob Cat A220 A300 T200 T550 T590 S...
# 4                       Frascos Dispenser Ambar 3Pçs Shampoo Condicion...
# ..                 ...                                                ...
# 129  dia do consumidor  Celular De Mesa Aquário Para Dois Chip Anatel ...
# 130  dia do consumidor  Kit 2 Escova Vassourinha Espanador De Pó Limpa...
# 131  dia do consumidor  Cabo De Alarme 2 Pares 0,40mm Megatron, Cobre,...
# 132  dia do consumidor  Brinquedo De Praia Regador Infantil De Plástic...
# 133  dia do consumidor  Suplemento Alimentar Para Cães Nutrafases Ômeg...
#
#                                               merged_2  \
# 0    Equaliv Body Protein 450G Proteina Isolada;Equ...
# 1                                 ; ; ; ;;;;; ; ; ; ;
# 2                                 ; ; ; ;;;;; ; ; ; ;
# 3                                 ; ; ; ;;;;; ; ; ; ;
# 4                                 ; ; ; ;;;;; ; ; ; ;
# ..                                                 ...
# 129  Fechadura Digital Fr 210; ; ; ;PRDX709VCMJSVL0...
# 130  Escova Espanadeira Cerdas Macias Limpeza Estof...
# 131  Cabo para camera de segurança bipolar cftv 100...
# 132  Boneca Sweet Reborn Primeira Vacina Acessórios...
# 133  Suplemento Alimentar - Nutrafases Ômega3 Com 2...
#
#                                               merged_3
# 0    Escova Rotativa 1200W Bivolt Essenza - Eb092 -...
# 1                                 ; ; ; ;;;;; ; ; ; ;
# 2                                 ; ; ; ;;;;; ; ; ; ;
# 3                                 ; ; ; ;;;;; ; ; ; ;
# 4                                 ; ; ; ;;;;; ; ; ; ;
# ..                                                 ...
# 129                                    ; ; ; ;;;;;;;;;
# 130                                    ; ; ; ;;;;;;;;;
# 131                                    ; ; ; ;;;;;;;;;
# 132                                    ; ; ; ;;;;;;;;;
# 133                                    ; ; ; ;;;;;;;;;
#
# [134 rows x 25 columns]
# ['Negociation_id_bd', 'negotiation_id', 'seller_id', 'number', 'model_tag', 'status', 'sentiments', 'sentiment_score', 'date_contact', 'last_update', 'strategy_tag', 'sender_number', 'number_status', 'cnpj', 'count_products', 'messageTag', 'sentiments', 'count_sku_stockout', 'produtos_campanha', 'thread_id', 'data_hoje', 'specialTag']
# C:\Users\matheus.marchiore\AppData\Local\Temp\ipykernel_2052\4167762569.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value ' ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna(' ', inplace=True)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2052\4167762569.py in ?()
# ---> 50 import pandas as pd
#      51 import json
#      52 import re
#      53
#
# c:\Users\matheus.marchiore\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in ?(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    9911         value_name: Hashable = "value",
#    9912         col_level: Level | None = None,
#    9913         ignore_index: bool = True,
#    9914     ) -> DataFrame:
# -> 9915         return melt(
#    9916             self,
#    9917             id_vars=id_vars,
#    9918             value_vars=value_vars,
#
# c:\Users\matheus.marchiore\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\melt.py in ?(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#     106
#     107     mdata: dict[Hashable, AnyArrayLike] = {}
#     108     for col in id_vars:
#     109         id_data = frame.pop(col)
# --> 110         if not isinstance(id_data.dtype, np.dtype):
#     111             # i.e. ExtensionDtype
#     112             if num_cols_adjusted > 0:
#     113                 mdata[col] = concat([id_data] * num_cols_adjusted, ignore_index=True)
#
# c:\Users\matheus.marchiore\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
import pandas as pd
import json
import re

# Carregando os dados do arquivo CSV
df = pd.read_csv('Planilha.csv')

# Função para converter JSON em dicionário
def parse_json(data):
    try:
        return json.loads(data)
    except json.JSONDecodeError:
        return {}  # Retorna um dicionário vazio em caso de erro

# Aplicar a função na coluna 'extra_info' para extrair o JSON
df['extra_info'] = df['extra_info'].apply(parse_json)

# Normalizar o conteúdo JSON em colunas separadas
json_cols = df['extra_info'].apply(pd.Series)

# Unir as novas colunas ao DataFrame original
df = pd.concat([df, json_cols], axis=1).drop('extra_info', axis=1)

# Preencher todos os valores nulos com espaço em branco
df.fillna(' ', inplace=True)

# Encontrar colunas que terminam com números e mesclar os valores
sufixos = {}
for col in df.columns:
    match = re.search(r'(\d+)$', col)
    if match:
        num = match.group(1)
        if num not in sufixos:
            sufixos[num] = []
        sufixos[num].append(col)

# Para cada grupo de sufixo, mesclar as colunas correspondentes
for num, columns in sufixos.items():
    df['merged_' + num] = df[columns].apply(lambda x: ';'.join(x.astype(str)), axis=1)
    df.drop(columns, axis=1, inplace=True)  # Remover as colunas originais se necessário

# Mostrar o DataFrame atualizado
print(df)

# Derreter as colunas mescladas
melted_df = df.melt(id_vars=[col for col in df.columns if not col.startswith('merged_')], 
                    value_vars=['merged_1', 'merged_2', 'merged_3'], 
                    var_name='Tipo_Mesclado', 
                    value_name='Mesclado')
print(melted_df)
# Out:
#      Negociation_id_bd  negotiation_id                             seller_id  \
# 0               152130          114920  bc579423-30f5-438c-8a15-1731ff5a1b66
# 1               152117          114921  fd8f557a-6d67-4a4c-8137-a8ccf3ca914f
# 2               152116          114922  f68442a2-676a-4532-86a1-7728076726e6
# 3               152115          114923  f6189c8d-7a53-4a8c-afa0-a3781bd66db7
# 4               152114          114924  f2406317-1668-4ba5-a6c7-2209b66489f0
# ..                 ...             ...                                   ...
# 129              19436           95871  db6383ee-a9dc-4455-8d41-7a9b30cef591
# 130              19435           95872  db39a676-e740-49cd-8bc2-4c51d9891386
# 131              19434           95873  db29f79d-ccec-4206-9885-e1d4125e7320
# 132              19433           95874  db24347c-93f2-424b-87ca-930645c0f86b
# 133              19432           95875  dab2b678-8ce4-4893-913a-cb3c779da35f
#
#             number                         model_tag         status  \
# 0    5541995659361                      samebrandpdf     in contact
# 1    5583996732622                    campanhageral1  first contact
# 2    5528999915535                    campanhageral1     in contact
# 3    5511943784797                    campanhageral1  first contact
# 4    5511944466250                    campanhageral1  first contact
# ..             ...                               ...            ...
# 129  5531995164635  campanhaespecialdiadoconsumidor2  first contact
# 130  5511990569952                fup2campanhageral2           fup2
# 131  5535988269425  campanhaespecialdiadoconsumidor2  first contact
# 132  5518981127302  campanhaespecialdiadoconsumidor2  first contact
# 133  5541998760031  campanhaespecialdiadoconsumidor2  first contact
#
#     sentiments sentiment_score                 date_contact  \
# 0                               2024-04-15T21:29:42.799793Z
# 1                               2024-04-15T19:31:59.850708Z
# 2                               2024-04-15T19:31:59.339031Z
# 3                               2024-04-15T19:31:58.829020Z
# 4                               2024-04-15T19:31:58.373461Z
# ..         ...             ...                          ...
# 129                             2024-03-15T16:26:29.178033Z
# 130                             2024-03-15T16:26:28.800038Z
# 131                             2024-03-15T16:26:28.391843Z
# 132                             2024-03-15T16:26:27.980767Z
# 133                             2024-03-15T16:26:27.598377Z
#
#                      last_update  ...               messageTag  \
# 0    2024-04-15T21:37:29.956591Z  ...        messagesamebrand1
# 1    2024-04-15T19:31:59.850718Z  ...         messagecampaign1
# 2    2024-04-15T19:45:23.764272Z  ...         messagecampaign4
# 3    2024-04-15T19:31:58.829031Z  ...         messagecampaign6
# 4    2024-04-15T19:31:58.373471Z  ...         messagecampaign3
# ..                           ...  ...                      ...
# 129  2024-03-15T16:26:29.178043Z  ...  messagespecialcampaign1
# 130  2024-03-20T21:24:57.572528Z  ...  messagespecialcampaign3
# 131  2024-03-15T16:26:28.391855Z  ...  messagespecialcampaign2
# 132  2024-03-15T16:26:27.980778Z  ...  messagespecialcampaign2
# 133  2024-03-15T16:26:27.598388Z  ...  messagespecialcampaign3
#
#                                             sentiments count_sku_stockout  \
# 0    {"sentiments":["neutro","neutro","neutro","neu...
# 1
# 2    {"sentiments":["neutro","neutro","conflito","r...
# 3
# 4
# ..                                                 ...                ...
# 129
# 130
# 131
# 132
# 133
#
#     produtos_campanha                        thread_id data_hoje  \
# 0
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ..                ...                              ...       ...
# 129                 2  thread_9tEJsbcEjhsge6ExpDlvozCa
# 130                 2  thread_tqxBwtglfjesW1waTbpTG6PR
# 131                 2  thread_NQH4ZsoCzUN4Go6WeHzAA10G
# 132                 2  thread_Z7jLdYaVm59fev932gCJlc1g
# 133                 2  thread_OeMBcVngojG3Fs9bvFTrun6i
#
#             specialTag                                           merged_1  \
# 0                       Equaliv Body Protein Cacau 100% Isolado Coláge...
# 1                       Mahogany Hidratante Desodorante Corporal Pytho...
# 2                       Tubolit  Massa Epóxi A+B 300G; ; ; ;PRDB0WQXUI...
# 3                       Kit Filtros Bob Cat A220 A300 T200 T550 T590 S...
# 4                       Frascos Dispenser Ambar 3Pçs Shampoo Condicion...
# ..                 ...                                                ...
# 129  dia do consumidor  Celular De Mesa Aquário Para Dois Chip Anatel ...
# 130  dia do consumidor  Kit 2 Escova Vassourinha Espanador De Pó Limpa...
# 131  dia do consumidor  Cabo De Alarme 2 Pares 0,40mm Megatron, Cobre,...
# 132  dia do consumidor  Brinquedo De Praia Regador Infantil De Plástic...
# 133  dia do consumidor  Suplemento Alimentar Para Cães Nutrafases Ômeg...
#
#                                               merged_2  \
# 0    Equaliv Body Protein 450G Proteina Isolada;Equ...
# 1                                 ; ; ; ;;;;; ; ; ; ;
# 2                                 ; ; ; ;;;;; ; ; ; ;
# 3                                 ; ; ; ;;;;; ; ; ; ;
# 4                                 ; ; ; ;;;;; ; ; ; ;
# ..                                                 ...
# 129  Fechadura Digital Fr 210; ; ; ;PRDX709VCMJSVL0...
# 130  Escova Espanadeira Cerdas Macias Limpeza Estof...
# 131  Cabo para camera de segurança bipolar cftv 100...
# 132  Boneca Sweet Reborn Primeira Vacina Acessórios...
# 133  Suplemento Alimentar - Nutrafases Ômega3 Com 2...
#
#                                               merged_3
# 0    Escova Rotativa 1200W Bivolt Essenza - Eb092 -...
# 1                                 ; ; ; ;;;;; ; ; ; ;
# 2                                 ; ; ; ;;;;; ; ; ; ;
# 3                                 ; ; ; ;;;;; ; ; ; ;
# 4                                 ; ; ; ;;;;; ; ; ; ;
# ..                                                 ...
# 129                                    ; ; ; ;;;;;;;;;
# 130                                    ; ; ; ;;;;;;;;;
# 131                                    ; ; ; ;;;;;;;;;
# 132                                    ; ; ; ;;;;;;;;;
# 133                                    ; ; ; ;;;;;;;;;
#
# [134 rows x 25 columns]
# C:\Users\matheus.marchiore\AppData\Local\Temp\ipykernel_2052\2015565393.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value ' ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna(' ', inplace=True)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2052\2015565393.py in ?()
# ---> 46 import pandas as pd
#      47 import json
#      48 import re
#      49
#
# c:\Users\matheus.marchiore\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in ?(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    9911         value_name: Hashable = "value",
#    9912         col_level: Level | None = None,
#    9913         ignore_index: bool = True,
#    9914     ) -> DataFrame:
# -> 9915         return melt(
#    9916             self,
#    9917             id_vars=id_vars,
#    9918             value_vars=value_vars,
#
# c:\Users\matheus.marchiore\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\melt.py in ?(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#     106
#     107     mdata: dict[Hashable, AnyArrayLike] = {}
#     108     for col in id_vars:
#     109         id_data = frame.pop(col)
# --> 110         if not isinstance(id_data.dtype, np.dtype):
#     111             # i.e. ExtensionDtype
#     112             if num_cols_adjusted > 0:
#     113                 mdata[col] = concat([id_data] * num_cols_adjusted, ignore_index=True)
#
# c:\Users\matheus.marchiore\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
import pandas as pd
import json
import re

# Carregando os dados do arquivo CSV
df = pd.read_csv('Planilha.csv')

# Função para converter JSON em dicionário
def parse_json(data):
    try:
        return json.loads(data)
    except json.JSONDecodeError:
        return {}  # Retorna um dicionário vazio em caso de erro

# Aplicar a função na coluna 'extra_info' para extrair o JSON
df['extra_info'] = df['extra_info'].apply(parse_json)

# Normalizar o conteúdo JSON em colunas separadas
json_cols = df['extra_info'].apply(pd.Series)

# Unir as novas colunas ao DataFrame original
df = pd.concat([df, json_cols], axis=1).drop('extra_info', axis=1)

# Preencher todos os valores nulos com espaço em branco
df.fillna(' ', inplace=True)

# Encontrar colunas que terminam com números e mesclar os valores
sufixos = {}
for col in df.columns:
    match = re.search(r'(\d+)$', col)
    if match:
        num = match.group(1)
        if num not in sufixos:
            sufixos[num] = []
        sufixos[num].append(col)

# Para cada grupo de sufixo, mesclar as colunas correspondentes
for num, columns in sufixos.items():
    df['merged_' + num] = df[columns].apply(lambda x: ';'.join(x.astype(str)), axis=1)
    df.drop(columns, axis=1, inplace=True)  # Remover as colunas originais se necessário

# Selecionando as colunas fixas corretamente
fixed_columns = df.columns.difference(['merged_1', 'merged_2', 'merged_3']).tolist()

# Certificando-se de que fixed_columns é uma lista
if not isinstance(fixed_columns, list):
    fixed_columns = list(fixed_columns)

# Utilizando o método melt corretamente
df = df.melt(id_vars=fixed_columns, value_vars=['merged_1', 'merged_2', 'merged_3'], var_name='Tipo_Mesclado', value_name='Mesclado')

# Verificando o DataFrame resultante
print(df.head())
